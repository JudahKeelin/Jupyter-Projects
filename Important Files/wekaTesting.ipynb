# %%
import os

os.environ["WEKA_JAR_PATH"] = "C:/Program Files/Weka-3-9-6/weka.jar" 
os.environ["JAVA_HOME"] = "C:/Program Files/Weka-3-9-6/jre/zulu17.32.13-ca-fx-jre17.0.2-win_x64/bin"

import librosa
import numpy as np
import parselmouth
from scipy.stats import iqr, skew, kurtosis
from scipy.signal import find_peaks
import pandas as pd
import math
import weka.core.jvm as jvm
from weka.core.converters import Loader
from weka.classifiers import Classifier
import weka
import weka.core.serialization as SerializationHelper
import sounddevice as sd
import numpy as np
from collections import deque
import joblib
from sklearn.preprocessing import StandardScaler
import keyboard
from time import sleep

# %%
def safe_formant_values(formant_obj, formant_index, duration):
    times = np.arange(0, duration, 0.01)
    values = [formant_obj.get_value_at_time(formant_index, t) for t in times]
    return [v for v in values if v is not None and not np.isnan(v) and v > 0]

def extract_features(audio, sr=16000):
    y = audio

    # Normalize audio
    y = y / np.max(np.abs(y)) if np.max(np.abs(y)) > 0 else y
    
    # Extract MFCCs (first 13 coefficients)
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
    delta_mfccs = librosa.feature.delta(mfccs)
    delta2_mfccs = librosa.feature.delta(mfccs, order=2)

    # Extract additional spectral features
    zcr = librosa.feature.zero_crossing_rate(y)[0]
    centroid = librosa.feature.spectral_centroid(y=y, sr=sr)[0]
    bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr)[0]
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)[0]
    flatness = librosa.feature.spectral_flatness(y=y)[0]
    contrast = librosa.feature.spectral_contrast(y=y, sr=sr)

    # Extract formants using parselmouth
    snd = parselmouth.Sound(y, sampling_frequency=sr)
    formant = snd.to_formant_burg()
    duration = snd.duration
    formants = [safe_formant_values(formant, i + 1, duration) for i in range(3)]

    # Extract pitch
    pitch = snd.to_pitch()
    pitches = pitch.selected_array['frequency'][pitch.selected_array['frequency'] > 0]

    # Extract harmonicity (HNR)
    harmonicity = snd.to_harmonicity_cc()
    hnr_values = harmonicity.values
    hnr_values = hnr_values[~np.isnan(hnr_values)]

    # Extract energy (RMS)
    energy = librosa.feature.rms(y=y)[0]

    # Statistical descriptors
    def compute_stats(data):
        skew_val = skew(data) if len(data) > 2 else 0
        kurt_val = kurtosis(data) if len(data) > 2 else 0
        skew_val = 0 if math.isnan(skew_val) else skew_val
        kurt_val = 0 if math.isnan(kurt_val) else kurt_val
        peak_count = len(find_peaks(data)[0]) if len(data) > 2 else 0
        range_val = (np.max(data) - np.min(data)) if len(data) > 0 else 0
        return {
            'mean': np.mean(data) if len(data) > 0 else 0,
            'median': np.median(data) if len(data) > 0 else 0,
            'std_dev': np.std(data) if len(data) > 0 else 0,
            'min': np.min(data) if len(data) > 0 else 0,
            'max': np.max(data) if len(data) > 0 else 0,
            'q1': np.percentile(data, 25) if len(data) > 0 else 0,
            'q3': np.percentile(data, 75) if len(data) > 0 else 0,
            'iqr': iqr(data) if len(data) > 0 else 0,
            'jitter': np.mean(np.abs(np.diff(data))) if len(data) > 1 else 0,
            'shimmer': np.std(np.abs(np.diff(data))) if len(data) > 1 else 0,
            'skewness': skew_val,
            'kurtosis': kurt_val,
            'peak_count': peak_count,
            'range': range_val
        }

    features = {}

    # Compute stats for MFCCs and their deltas
    for i in range(13):
        mfcc_stats = compute_stats(mfccs[i])
        delta_stats = compute_stats(delta_mfccs[i])
        delta2_stats = compute_stats(delta2_mfccs[i])
        for stat, value in mfcc_stats.items():
            features[f'mfcc_{i+1}_{stat}'] = value
        for stat, value in delta_stats.items():
            features[f'mfcc_{i+1}_delta_{stat}'] = value
        for stat, value in delta2_stats.items():
            features[f'mfcc_{i+1}_delta2_{stat}'] = value

    # Compute stats for spectral features
    for name, array in zip(
        ['zcr', 'spectral_centroid', 'spectral_bandwidth', 'spectral_rolloff', 'spectral_flatness'],
        [zcr, centroid, bandwidth, rolloff, flatness]
    ):
        stats = compute_stats(array)
        for stat, value in stats.items():
            features[f'{name}_{stat}'] = value

    for i in range(contrast.shape[0]):
        stats = compute_stats(contrast[i])
        for stat, value in stats.items():
            features[f'spectral_contrast_{i+1}_{stat}'] = value

    # Compute stats for Formants
    for i in range(3):
        formant_stats = compute_stats(formants[i])
        for stat, value in formant_stats.items():
            features[f'formant_{i+1}_{stat}'] = value

    # Compute stats for Pitch
    pitch_stats = compute_stats(pitches)
    for stat, value in pitch_stats.items():
        features[f'pitch_{stat}'] = value

    # Compute stats for Energy
    energy_stats = compute_stats(energy)
    for stat, value in energy_stats.items():
        features[f'energy_{stat}'] = value

    # Compute stats for Harmonicity (HNR)
    hnr_stats = compute_stats(hnr_values)
    for stat, value in hnr_stats.items():
        features[f'harmonicity_{stat}'] = value

    return features

# %%
jvm.start(packages=True)
# Out:
# DEBUG:weka.core.jvm:Adding bundled jars
# DEBUG:weka.core.jvm:Classpath=['c:\\Users\\jbkee\\Desktop\\Jupyter-Projects\\.venv\\Lib\\site-packages\\weka\\lib\\arpack_combined.jar', 'c:\\Users\\jbkee\\Desktop\\Jupyter-Projects\\.venv\\Lib\\site-packages\\weka\\lib\\core.jar', 'c:\\Users\\jbkee\\Desktop\\Jupyter-Projects\\.venv\\Lib\\site-packages\\weka\\lib\\mtj.jar', 'c:\\Users\\jbkee\\Desktop\\Jupyter-Projects\\.venv\\Lib\\site-packages\\weka\\lib\\python-weka-wrapper.jar', 'c:\\Users\\jbkee\\Desktop\\Jupyter-Projects\\.venv\\Lib\\site-packages\\weka\\lib\\weka.jar']
# DEBUG:weka.core.jvm:MaxHeapSize=default
# DEBUG:weka.core.jvm:Package support enabled

# %%
# jvm.stop()

# %%
# 2) Load your ARFF header (so we know the attribute layout)
loader = Loader(classname="weka.core.converters.ArffLoader")
header = loader.load_file("ThreeClassStackReducedSet.arff")
header.class_is_last()

attributes = []
for i in range(header.num_attributes):
    name = header.attribute(i).name
    if name != "emotion":
        attributes.append(header.attribute(i).name)
additional_attributes = ["energy_iqr", "energy_jitter", "energy_kurtosis", "energy_max", "energy_mean", "energy_median", "energy_peak_count", "energy_q3", "energy_range", "energy_shimmer"]
attributes.extend(additional_attributes)
print("Attributes in the header: ", attributes)

# 3) Load the serialized model
jobject=SerializationHelper.read("ThreeClassStacking.model")
print(jobject)
cls = Classifier(jobject)
print(cls)

# 4) Live audio capture (example with sounddevice & a 5 s rolling buffer)

sr = 16000

# Create a rolling buffer to store the last 5 seconds of audio
buf = deque(maxlen=sr*10)

# Define the audio callback function to capture audio
def audio_callback(indata, frames, time, status):
    buf.extend(indata[:,0])

stream = sd.InputStream(samplerate=sr, channels=1, callback=audio_callback)

scaler = joblib.load("librossa_scaler.save")
assert isinstance(scaler, StandardScaler), "Scaler is not a StandardScaler instance."
# Out:
# Attributes in the header:  ['pitch_q3', 'pitch_median', 'pitch_mean', 'pitch_q1', 'spectral_centroid_q1', 'mfcc_3_mean', 'pitch_shimmer', 'mfcc_3_q1', 'spectral_flatness_q1', 'pitch_jitter', 'pitch_range', 'mfcc_1_delta_min', 'pitch_iqr', 'mfcc_3_q3', 'mfcc_2_mean', 'spectral_flatness_median', 'spectral_rolloff_q1', 'mfcc_2_q3', 'mfcc_3_median', 'pitch_max', 'spectral_centroid_mean', 'mfcc_3_min', 'mfcc_5_min', 'spectral_centroid_median', 'energy_q1', 'mfcc_4_min', 'mfcc_2_iqr', 'zcr_q1', 'pitch_std_dev', 'mfcc_4_mean', 'mfcc_2_max', 'mfcc_4_q1', 'zcr_std_dev', 'mfcc_2_median', 'mfcc_1_delta_skewness', 'spectral_centroid_min', 'spectral_contrast_1_mean', 'mfcc_2_q1', 'spectral_bandwidth_median', 'mfcc_6_std_dev', 'mfcc_3_max', 'energy_min', 'zcr_q3', 'mfcc_13_std_dev', 'mfcc_3_jitter', 'mfcc_2_jitter', 'mfcc_6_delta_std_dev', 'zcr_iqr', 'mfcc_1_jitter', 'zcr_range', 'mfcc_2_delta_jitter', 'mfcc_2_std_dev', 'mfcc_2_delta2_std_dev', 'mfcc_6_delta_shimmer', 'mfcc_13_range', 'mfcc_6_min', 'spectral_bandwidth_q1', 'mfcc_6_delta2_shimmer', 'mfcc_1_delta2_shimmer', 'mfcc_2_delta2_max', 'mfcc_4_q3', 'energy_iqr', 'energy_jitter', 'energy_kurtosis', 'energy_max', 'energy_mean', 'energy_median', 'energy_peak_count', 'energy_q3', 'energy_range', 'energy_shimmer']
# Stacking
#
# Base classifiers
#
# Sigmoid Node 0
#     Inputs    Weights
#     Threshold    0.5143263851987505
#     Node 3    -0.4211486762101727
#     Node 4    -5.560956705700138
#     Node 5    -3.1689211935669945
#     Node 6    0.12530219303659512
#     Node 7    5.5238926103347845
#     Node 8    -1.6089040860276362
#     Node 9    0.3839215204163788
#     Node 10    -0.46520445863758847
#     Node 11    -0.47785770670046507
#     Node 12    1.830429877224501
#     Node 13    4.140701040900954
#     Node 14    -0.26937300423258254
#     Node 15    2.286234017790374
#     Node 16    -2.015833699399893
#     Node 17    -1.3565376489455936
#     Node 18    0.7867362891731217
#     Node 19    -0.47516266913265415
#     Node 20    5.228396880252594
#     Node 21    -0.40204896455253963
#     Node 22    1.6204406537093563
#     Node 23    -2.8006901059937355
#     Node 24    -0.18947437906837855
#     Node 25    6.043328375447243
#     Node 26    1.9365237413262804
#     Node 27    -0.6234745696514901
#     Node 28    -0.4768101396575576
#     Node 29    -3.918050457113132
#     Node 30    4.525597080896044
#     Node 31    1.535357659134099
#     Node 32    -0.4283805522616595
#     Node 33    0.5480013822691109
#     Node 34    -0.20172724385175128
#     Node 35    3.961544705593611
#     Node 36    -0.23944468286322879
#     Node 37    -3.4306060153403557
#     Node 38    -5.433216351940317
#     Node 39    2.2408583806600797
#     Node 40    -0.17932395299807333
#     Node 41    2.217840333441453
#     Node 42    -1.2961536017552773
#     Node 43    0.2064882253339271
#     Node 44    -5.505294214828745
#     Node 45    0.010231144920239446
#     Node 46    -0.4824989437826248
#     Node 47    2.439084730744645
#     Node 48    -3.924894595574113
#     Node 49    6.951625689075842
#     Node 50    3.9002613001377395
#     Node 51    0.1758782678134311
#     Node 52    -5.458239312158033
#     Node 53    -0.041173109539662925
#     Node 54    6.2902747361943145
#     Node 55    -1.387647812304166
#     Node 56    -1.6844924076352876
#     Node 57    -0.20361199294167845
#     Node 58    0.04591239752711639
#     Node 59    0.19105964407499687
#     Node 60    0.22723870492196624
#     Node 61    0.049250020221807085
#     Node 62    -5.239709981695785
#     Node 63    2.633849929241158
#     Node 64    -4.4489615123403725
#     Node 65    7.035042239211875
#     Node 66    5.055235704135638
#     Node 67    3.359213105882584
#     Node 68    1.393913103491473
#     Node 69    -5.8611710325565936
#     Node 70    -0.2124789735886739
#     Node 71    -1.9922374222803512
# Sigmoid Node 1
#     Inputs    Weights
#     Threshold    -0.43024119066119154
#     Node 3    2.0319762306441773
#     Node 4    4.942269896262594
#     Node 5    2.331448822523823
#     Node 6    -0.49321194252599915
#     Node 7    -4.993816137194377
#     Node 8    -1.415220083376258
#     Node 9    -0.7155396027134359
#     Node 10    0.40782382641373527
#     Node 11    0.6827609029575088
#     Node 12    -1.4910711781508126
#     Node 13    -5.004755371126045
#     Node 14    -0.5738964547789164
#     Node 15    -2.1677576809534433
#     Node 16    1.3946147218386415
#     Node 17    3.386184979603977
#     Node 18    -0.161468845362767
#     Node 19    -1.587404137403725
#     Node 20    -3.1580935536965384
#     Node 21    0.1670677349522582
#     Node 22    -1.267073475118933
#     Node 23    -1.8567976268717794
#     Node 24    0.2787575271003414
#     Node 25    -3.519139406353055
#     Node 26    -1.592040905426383
#     Node 27    0.666650900606243
#     Node 28    5.50086818314235
#     Node 29    -1.1064231062527177
#     Node 30    -4.128332847052784
#     Node 31    -1.1696940481253177
#     Node 32    0.3336540971260073
#     Node 33    -1.7259810970381722
#     Node 34    0.19422519493994994
#     Node 35    -2.5142212562404325
#     Node 36    -1.5725194370274815
#     Node 37    4.577063404209265
#     Node 38    1.0886704633661257
#     Node 39    -1.5975224990131844
#     Node 40    -0.056774666021216884
#     Node 41    0.66793301328819
#     Node 42    0.8312650818522167
#     Node 43    -0.6527031332173122
#     Node 44    5.172622083563995
#     Node 45    -1.0465830883728182
#     Node 46    2.2884441624026493
#     Node 47    -1.8655423019300637
#     Node 48    0.10576248310328487
#     Node 49    -1.9672122568742718
#     Node 50    -5.062926309111811
#     Node 51    -1.7967875794127857
#     Node 52    3.9099063590624987
#     Node 53    -0.758459298168783
#     Node 54    -6.379687285894565
#     Node 55    4.7618717365430285
#     Node 56    1.6959596644812789
#     Node 57    -0.6475135885381121
#     Node 58    0.04801207321484186
#     Node 59    -0.5508846777154333
#     Node 60    3.9818182682236927
#     Node 61    -1.242077105268658
#     Node 62    -0.7225650879508312
#     Node 63    -2.467725605560298
#     Node 64    3.937783245238715
#     Node 65    -3.551816951300025
#     Node 66    -3.2787566930211143
#     Node 67    -3.7364994962539537
#     Node 68    -1.986980684692893
#     Node 69    -1.2266693587686275
#     Node 70    -1.0183248390298736
#     Node 71    1.1255782623797133
# Sigmoid Node 2
#     Inputs    Weights
#     Threshold    -0.5103522448671741
#     Node 3    0.6592309287744194
#     Node 4    -3.2931788150976415
#     Node 5    -0.8673619688732827
#     Node 6    -0.24105420445243436
#     Node 7    -1.1444705377780466
#     Node 8    5.809964603582955
#     Node 9    -0.10700874844993104
#     Node 10    -0.13529082746797397
#     Node 11    -1.9297561089267075
#     Node 12    -0.7927483680283705
#     Node 13    -1.1242360334229005
#     Node 14    -0.376237005669903
#     Node 15    -1.2818841881781327
#     Node 16    -0.8693316963453774
#     Node 17    -0.9028943705684769
#     Node 18    -2.342999309105836
#     Node 19    -0.36595317927521465
#     Node 20    -3.7877189522583565
#     Node 21    0.6575350835156086
#     Node 22    -0.4252335812147321
#     Node 23    3.351794704921303
#     Node 24    0.20999000028713344
#     Node 25    -4.789720484846998
#     Node 26    -1.1807725664477975
#     Node 27    -0.675159585837483
#     Node 28    -4.135263193192231
#     Node 29    4.207853091417719
#     Node 30    -0.6102153432534082
#     Node 31    0.3274647121217975
#     Node 32    0.15514574697668504
#     Node 33    1.8979263593125855
#     Node 34    -0.51161970781155
#     Node 35    -1.873277170870771
#     Node 36    1.0072552353537312
#     Node 37    -0.07172087319362913
#     Node 38    6.2282224303180564
#     Node 39    -4.38152282683092
#     Node 40    -1.3068424436888881
#     Node 41    -2.5427065947013086
#     Node 42    2.365036879622831
#     Node 43    0.43241587244956875
#     Node 44    0.13094555635600794
#     Node 45    -1.8096078436412877
#     Node 46    -0.5585851141693338
#     Node 47    -0.8624860225704868
#     Node 48    4.473642217784907
#     Node 49    -5.510858636981358
#     Node 50    1.273280769719719
#     Node 51    2.178212869894523
#     Node 52    2.4997558682774543
#     Node 53    0.4659884972812348
#     Node 54    -4.340425541877212
#     Node 55    -3.5832202596981237
#     Node 56    -0.4600276951810605
#     Node 57    -0.27622091915366453
#     Node 58    0.03612584968735946
#     Node 59    -0.27485778606779154
#     Node 60    -3.8447250472488257
#     Node 61    -0.30640648136388837
#     Node 62    3.554345616245048
#     Node 63    -1.6693125831175522
#     Node 64    2.0425625130635465
#     Node 65    -4.455744673581932
#     Node 66    -3.9154177072546457
#     Node 67    -0.5194839779623929
#     Node 68    0.8378869659309042
#     Node 69    4.508359020822881
#     Node 70    -0.3023382430963685
#     Node 71    0.6748100147056839
# Sigmoid Node 3
#     Inputs    Weights
#     Threshold    -0.1727650621179545
#     Attrib pitch_median    0.40976458314381753
#     Attrib pitch_q3    0.11873969945035479
#     Attrib pitch_mean    -0.6105317589460181
#     Attrib pitch_q1    -0.3165480226707718
#     Attrib spectral_contrast_7_iqr    0.2759927172729289
#     Attrib mfcc_3_mean    0.0711477500815024
#     Attrib spectral_contrast_7_std_dev    0.161222874226807
#     Attrib mfcc_3_q1    0.5565899298950007
#     Attrib pitch_jitter    0.5353181295623952
#     Attrib mfcc_3_q3    0.24574495592329904
#     Attrib spectral_contrast_7_q3    0.2987729229790226
#     Attrib pitch_shimmer    -0.17786938966829383
#     Attrib pitch_iqr    0.4197178912361652
#     Attrib pitch_range    0.7499290422479102
#     Attrib spectral_centroid_median    -0.10801002422739715
#     Attrib zcr_mean    -0.4859646400242278
#     Attrib mfcc_2_mean    0.3968386285279593
#     Attrib mfcc_4_mean    -0.1568844225948811
#     Attrib energy_q1    0.12477252439584023
#     Attrib mfcc_2_q3    0.2804329061175822
#     Attrib mfcc_4_max    -0.2237581652036199
#     Attrib spectral_flatness_min    -0.014968594788192105
#     Attrib mfcc_3_median    0.6781458278016762
#     Attrib zcr_median    -0.7608007266646951
#     Attrib pitch_max    -0.026251562237266345
#     Attrib zcr_q3    0.107545461526467
#     Attrib spectral_contrast_7_median    0.1209594821395246
#     Attrib mfcc_11_mean    -0.20570570120158388
#     Attrib spectral_contrast_7_q1    0.17269903611805798
#     Attrib mfcc_6_median    0.4237839375356577
#     Attrib mfcc_6_q3    1.5360643199557977
#     Attrib spectral_centroid_q3    0.5704538079554666
#     Attrib mfcc_3_min    0.11858726159956173
#     Attrib spectral_contrast_7_mean    0.3853083725031315
#     Attrib mfcc_4_q1    -0.6182623885375813
#     Attrib mfcc_6_mean    0.32679492639737173
#     Attrib mfcc_2_max    0.2660663838414728
#     Attrib spectral_rolloff_median    0.30302811350987585
#     Attrib pitch_std_dev    1.1886457382067368
#     Attrib mfcc_4_median    0.398286338432426
#     Attrib spectral_rolloff_mean    0.39421141722010306
#     Attrib mfcc_11_q1    0.46429612359303
#     Attrib zcr_std_dev    -0.530537375816739
#     Attrib mfcc_6_min    -0.4542090784673759
#     Attrib mfcc_2_q1    0.18898419059221153
#     Attrib mfcc_4_q3    -0.22139830072686087
#     Attrib mfcc_3_max    0.39254764263897896
#     Attrib mfcc_11_min    -0.3519722724888851
#     Attrib spectral_contrast_7_max    -0.018408855368862657
#     Attrib mfcc_5_mean    0.6490197901754341
#     Attrib spectral_rolloff_q3    0.4369060590717729
#     Attrib mfcc_11_median    -0.12273752342745628
#     Attrib mfcc_5_q3    0.7400638621568187
#     Attrib zcr_q1    0.37045134194032475
#     Attrib spectral_contrast_7_kurtosis    -0.2558043387128413
#     Attrib energy_min    -0.21732821154179946
#     Attrib spectral_contrast_2_q3    -2.0479662978168225
#     Attrib zcr_range    -0.10779287122363024
#     Attrib spectral_rolloff_q1    0.6164459261909253
#     Attrib mfcc_11_q3    0.5029650423377227
#     Attrib zcr_max    0.3356314533447562
#     Attrib zcr_iqr    -0.396983244558481
#     Attrib formant_1_q1    0.17746459151525693
#     Attrib mfcc_5_max    -0.29275733683818944
#     Attrib mfcc_2_median    0.09476600725474559
#     Attrib spectral_flatness_q1    -0.7622095033647979
# Sigmoid Node 4
#     Inputs    Weights
#     Threshold    -0.08038819000761943
#     Attrib pitch_median    0.42830682913951507
#     Attrib pitch_q3    0.6057809425284069
#     Attrib pitch_mean    -0.17863121175975782
#     Attrib pitch_q1    0.3262540618512552
#     Attrib spectral_contrast_7_iqr    2.4456269607511256
#     Attrib mfcc_3_mean    -1.5051992445789584
#     Attrib spectral_contrast_7_std_dev    0.08934996895670509
#     Attrib mfcc_3_q1    -0.5924649305553072
#     Attrib pitch_jitter    0.03574181203870892
#     Attrib mfcc_3_q3    -1.621377299351233
#     Attrib spectral_contrast_7_q3    1.601377398952986
#     Attrib pitch_shimmer    -1.7872014260002163
#     Attrib pitch_iqr    1.4289559371097547
#     Attrib pitch_range    0.793415103209184
#     Attrib spectral_centroid_median    -0.6566006972285292
#     Attrib zcr_mean    0.23565096170816488
#     Attrib mfcc_2_mean    -1.005944912662037
#     Attrib mfcc_4_mean    -1.507335429850741
#     Attrib energy_q1    1.1341486605399582
#     Attrib mfcc_2_q3    0.2783290662397012
#     Attrib mfcc_4_max    -3.148239308158314
#     Attrib spectral_flatness_min    0.4499163820872114
#     Attrib mfcc_3_median    -0.05991536727493927
#     Attrib zcr_median    -2.180685931765536
#     Attrib pitch_max    0.44277714696278125
#     Attrib zcr_q3    2.049947337913616
#     Attrib spectral_contrast_7_median    -0.5056195278776029
#     Attrib mfcc_11_mean    -1.6549304823324535
#     Attrib spectral_contrast_7_q1    -0.6749168831607761
#     Attrib mfcc_6_median    1.8960608599945803
#     Attrib mfcc_6_q3    1.4639704488272591
#     Attrib spectral_centroid_q3    -0.9905253821682318
#     Attrib mfcc_3_min    -2.2494063727929285
#     Attrib spectral_contrast_7_mean    0.25392353247849797
#     Attrib mfcc_4_q1    -0.4841172731126783
#     Attrib mfcc_6_mean    2.406526891938007
#     Attrib mfcc_2_max    0.9802791713621613
#     Attrib spectral_rolloff_median    0.19975428342353724
#     Attrib pitch_std_dev    2.4838999150466727
#     Attrib mfcc_4_median    -0.5502663006354048
#     Attrib spectral_rolloff_mean    0.32011885982491217
#     Attrib mfcc_11_q1    -1.096647183173322
#     Attrib zcr_std_dev    -0.7645523269355805
#     Attrib mfcc_6_min    -1.8273601751816764
#     Attrib mfcc_2_q1    -0.4920341309862616
#     Attrib mfcc_4_q3    -1.5496291656224699
#     Attrib mfcc_3_max    -1.6089310769621628
#     Attrib mfcc_11_min    -0.30570299191752387
#     Attrib spectral_contrast_7_max    0.14229386923738724
#     Attrib mfcc_5_mean    2.973578879304449
#     Attrib spectral_rolloff_q3    -0.10023652820148364
#     Attrib mfcc_11_median    -2.4594518874060434
#     Attrib mfcc_5_q3    1.7140513776670083
#     Attrib zcr_q1    1.490172753297392
#     Attrib spectral_contrast_7_kurtosis    -0.3796307521415612
#     Attrib energy_min    0.22722178073249047
#     Attrib spectral_contrast_2_q3    0.7159810175656351
#     Attrib zcr_range    0.20766261650764428
#     Attrib spectral_rolloff_q1    0.6410395211934015
#     Attrib mfcc_11_q3    -0.08265879294640703
#     Attrib zcr_max    -0.47392643845252874
#     Attrib zcr_iqr    1.103924472535855
#     Attrib formant_1_q1    -1.195849586222118
#     Attrib mfcc_5_max    0.44349889799917114
#     Attrib mfcc_2_median    -1.8705752791151853
#     Attrib spectral_flatness_q1    -1.107120849066029
# Sigmoid Node 5
#     Inputs    Weights
#     Threshold    -0.19273247163298368
#     Attrib pitch_median    0.7023970046467515
#     Attrib pitch_q3    0.5645863689676185
#     Attrib pitch_mean    0.21283969843797879
#     Attrib pitch_q1    0.6033970887803578
#     Attrib spectral_contrast_7_iqr    0.9292769557521194
#     Attrib mfcc_3_mean    -0.7735880262917908
#     Attrib spectral_contrast_7_std_dev    0.7217766533878133
#     Attrib mfcc_3_q1    -0.5880588060874283
#     Attrib pitch_jitter    0.8113451883755441
#     Attrib mfcc_3_q3    -0.17592677285464522
#     Attrib spectral_contrast_7_q3    0.6433314994207661
#     Attrib pitch_shimmer    0.2250874773972374
#     Attrib pitch_iqr    0.2060939723142524
#     Attrib pitch_range    -0.16103584147828415
#     Attrib spectral_centroid_median    0.3515143868947071
#     Attrib zcr_mean    0.5076903914181137
#     Attrib mfcc_2_mean    -1.0806725192134303
#     Attrib mfcc_4_mean    0.32250780723110445
#     Attrib energy_q1    0.047146364134802124
#     Attrib mfcc_2_q3    -0.588535117958683
#     Attrib mfcc_4_max    -0.03304135212011293
#     Attrib spectral_flatness_min    0.36521239050930643
#     Attrib mfcc_3_median    -0.009086096252981114
#     Attrib zcr_median    0.2145850667399796
#     Attrib pitch_max    -0.6154818539174245
#     Attrib zcr_q3    1.2089135052298174
#     Attrib spectral_contrast_7_median    -0.2724173884397554
#     Attrib mfcc_11_mean    0.292326961651713
#     Attrib spectral_contrast_7_q1    -0.11784553606425557
#     Attrib mfcc_6_median    -0.5842161696580122
#     Attrib mfcc_6_q3    -0.28622193875619123
#     Attrib spectral_centroid_q3    1.3437930923526942
#     Attrib mfcc_3_min    -1.3407317014107074
#     Attrib spectral_contrast_7_mean    0.31311253441951925
#     Attrib mfcc_4_q1    0.21766719508441712
#     Attrib mfcc_6_mean    -0.1959254883006159
#     Attrib mfcc_2_max    -1.1444407050849068
#     Attrib spectral_rolloff_median    0.27043174523549834
#     Attrib pitch_std_dev    0.7331266027750656
#     Attrib mfcc_4_median    0.3332585160407747
#     Attrib spectral_rolloff_mean    0.19129157961158008
#     Attrib mfcc_11_q1    0.6167599279694741
#     Attrib zcr_std_dev    0.4329439181272301
#     Attrib mfcc_6_min    -0.1752436966523961
#     Attrib mfcc_2_q1    -0.6848473506993705
#     Attrib mfcc_4_q3    0.07281855546804772
#     Attrib mfcc_3_max    0.02101834853055007
#     Attrib mfcc_11_min    -0.20179297550728736
#     Attrib spectral_contrast_7_max    0.17793978562953752
#     Attrib mfcc_5_mean    0.3158534997131876
#     Attrib spectral_rolloff_q3    0.8660760524405958
#     Attrib mfcc_11_median    0.07492552506621816
#     Attrib mfcc_5_q3    0.08928495740738199
#     Attrib zcr_q1    0.5197111735926315
#     Attrib spectral_contrast_7_kurtosis    0.3412161920830351
#     Attrib energy_min    0.1392461451233783
#     Attrib spectral_contrast_2_q3    0.37861709806969224
#     Attrib zcr_range    0.4155200730703809
#     Attrib spectral_rolloff_q1    0.4770816935891879
#     Attrib mfcc_11_q3    -0.21774623927975617
#     Attrib zcr_max    0.30444049236879567
#     Attrib zcr_iqr    1.0137336404677177
#     Attrib formant_1_q1    -0.2653550851104163
#     Attrib mfcc_5_max    -0.13714953955077105
#     Attrib mfcc_2_median    -1.184251078765109
#     Attrib spectral_flatness_q1    0.2532242680356505
# Sigmoid Node 6
#     Inputs    Weights
#     Threshold    -0.12431808659003557
#     Attrib pitch_median    -0.06705023395385196
#     Attrib pitch_q3    -0.011380355909904908
#     Attrib pitch_mean    0.2087565739392916
#     Attrib pitch_q1    0.12389794674266703
#     Attrib spectral_contrast_7_iqr    0.12707631878025522
#     Attrib mfcc_3_mean    0.08986322481519939
#     Attrib spectral_contrast_7_std_dev    0.11005762986729904
#     Attrib mfcc_3_q1    0.04751485334232041
#     Attrib pitch_jitter    0.03898580102528401
#     Attrib mfcc_3_q3    0.027317548308323624
#     Attrib spectral_contrast_7_q3    0.0844067006501809
#     Attrib pitch_shimmer    0.2554783469253462
#     Attrib pitch_iqr    0.014997977606609715
#     Attrib pitch_range    0.11005295286975882
#     Attrib spectral_centroid_median    0.16176046069740274
#     Attrib zcr_mean    9.702105331304672E-4
#     Attrib mfcc_2_mean    0.0903277099078595
#     Attrib mfcc_4_mean    -0.026207652586992022
#     Attrib energy_q1    -0.03694416590000172
#     Attrib mfcc_2_q3    0.03145811151532568
#     Attrib mfcc_4_max    0.03152682490277201
#     Attrib spectral_flatness_min    0.14733411607327565
#     Attrib mfcc_3_median    -0.015497287299115847
#     Attrib zcr_median    0.1935583913939818
#     Attrib pitch_max    0.10539958068863585
#     Attrib zcr_q3    -0.12881956090130367
#     Attrib spectral_contrast_7_median    0.09355535591211171
#     Attrib mfcc_11_mean    0.14777958269407956
#     Attrib spectral_contrast_7_q1    -0.07087321008960196
#     Attrib mfcc_6_median    0.048888383951979315
#     Attrib mfcc_6_q3    -0.1655837552369536
#     Attrib spectral_centroid_q3    -2.2668608916656547E-4
#     Attrib mfcc_3_min    -2.951979212236443E-4
#     Attrib spectral_contrast_7_mean    -0.023519826260827083
#     Attrib mfcc_4_q1    0.07601569122270999
#     Attrib mfcc_6_mean    -0.05178319783064007
#     Attrib mfcc_2_max    0.12130656643379636
#     Attrib spectral_rolloff_median    0.20077960179497134
#     Attrib pitch_std_dev    0.019445022206755303
#     Attrib mfcc_4_median    -0.16740396584531173
#     Attrib spectral_rolloff_mean    0.021528714347333423
#     Attrib mfcc_11_q1    -0.06479809141303991
#     Attrib zcr_std_dev    -0.041532739584070756
#     Attrib mfcc_6_min    0.16670827388255746
#     Attrib mfcc_2_q1    0.0673558181548186
#     Attrib mfcc_4_q3    0.04791121614956604
#     Attrib mfcc_3_max    -0.25611450463539587
#     Attrib mfcc_11_min    0.12349455304096786
#     Attrib spectral_contrast_7_max    0.08637936222730112
#     Attrib mfcc_5_mean    -0.09401465822681794
#     Attrib spectral_rolloff_q3    -0.08820333308498211
#     Attrib mfcc_11_median    0.08086171692488052
#     Attrib mfcc_5_q3    -0.15381535012265665
#     Attrib zcr_q1    -0.018773858906372277
#     Attrib spectral_contrast_7_kurtosis    0.15689544101484298
#     Attrib energy_min    0.22794802703755143
#     Attrib spectral_contrast_2_q3    -0.045599873121246845
#     Attrib zcr_range    -0.09603700151131143
#     Attrib spectral_rolloff_q1    0.1283262551263851
#     Attrib mfcc_11_q3    -0.041588225169072894
#     Attrib zcr_max    -0.15717645040433673
#     Attrib zcr_iqr    0.017631548964534553
#     Attrib formant_1_q1    0.14875267758926178
#     Attrib mfcc_5_max    0.12220585665822466
#     Attrib mfcc_2_median    0.026604279195070295
#     Attrib spectral_flatness_q1    0.3223398447460866
# Sigmoid Node 7
#     Inputs    Weights
#     Threshold    -1.0138393032353634
#     Attrib pitch_median    -2.329371428906786
#     Attrib pitch_q3    -2.5649015491336953
#     Attrib pitch_mean    -0.7330262374790615
#     Attrib pitch_q1    -0.12290753666349452
#     Attrib spectral_contrast_7_iqr    1.499385759195384
#     Attrib mfcc_3_mean    -0.26067015556630546
#     Attrib spectral_contrast_7_std_dev    0.6280111589945081
#     Attrib mfcc_3_q1    -0.4818981282911007
#     Attrib pitch_jitter    1.1340771331062656
#     Attrib mfcc_3_q3    -0.7300799350838123
#     Attrib spectral_contrast_7_q3    1.0446171942118587
#     Attrib pitch_shimmer    0.8417689735987496
#     Attrib pitch_iqr    -2.4153060146952026
#     Attrib pitch_range    -0.05215823847530587
#     Attrib spectral_centroid_median    0.8149484032916623
#     Attrib zcr_mean    0.09215180116338534
#     Attrib mfcc_2_mean    -1.5747744952850697
#     Attrib mfcc_4_mean    -0.29855717648425556
#     Attrib energy_q1    0.5170142338327834
#     Attrib mfcc_2_q3    -2.014589441850103
#     Attrib mfcc_4_max    -2.869648093582297
#     Attrib spectral_flatness_min    1.5708489919732098
#     Attrib mfcc_3_median    0.440592057188255
#     Attrib zcr_median    1.5228782396772553
#     Attrib pitch_max    0.7878765752268693
#     Attrib zcr_q3    -1.1819548884171587
#     Attrib spectral_contrast_7_median    0.8783941503217474
#     Attrib mfcc_11_mean    -0.4140924431555708
#     Attrib spectral_contrast_7_q1    -0.04721725707162139
#     Attrib mfcc_6_median    0.9666912207742486
#     Attrib mfcc_6_q3    0.29143513044145297
#     Attrib spectral_centroid_q3    -0.1778863474469372
#     Attrib mfcc_3_min    0.28466735130225507
#     Attrib spectral_contrast_7_mean    0.28220274725667
#     Attrib mfcc_4_q1    0.17558209675851255
#     Attrib mfcc_6_mean    1.0488037427165833
#     Attrib mfcc_2_max    -0.8389433145886542
#     Attrib spectral_rolloff_median    -0.7450914907779712
#     Attrib pitch_std_dev    -1.201937972594822
#     Attrib mfcc_4_median    -1.6217536981096066
#     Attrib spectral_rolloff_mean    -0.21843711538234323
#     Attrib mfcc_11_q1    -0.2733949071194405
#     Attrib zcr_std_dev    -0.7864525301339181
#     Attrib mfcc_6_min    1.9349074595443427
#     Attrib mfcc_2_q1    -0.4268157601955731
#     Attrib mfcc_4_q3    -2.1553946905157892
#     Attrib mfcc_3_max    -1.1445406141767736
#     Attrib mfcc_11_min    0.7595814621153557
#     Attrib spectral_contrast_7_max    -2.6707710385030197
#     Attrib mfcc_5_mean    1.191297455923688
#     Attrib spectral_rolloff_q3    -1.0045351054688167
#     Attrib mfcc_11_median    -1.3032716451211215
#     Attrib mfcc_5_q3    -0.9688024579092176
#     Attrib zcr_q1    -0.39494804790843097
#     Attrib spectral_contrast_7_kurtosis    0.4606061142350229
#     Attrib energy_min    1.3879842806342564
#     Attrib spectral_contrast_2_q3    0.2909895860147935
#     Attrib zcr_range    -0.7629415662671718
#     Attrib spectral_rolloff_q1    1.5352825500075236
#     Attrib mfcc_11_q3    -0.6429688444651083
#     Attrib zcr_max    -1.1400020355627642
#     Attrib zcr_iqr    0.05188884671358974
#     Attrib formant_1_q1    0.39266210209647406
#     Attrib mfcc_5_max    -0.08446860974675952
#     Attrib mfcc_2_median    -1.4622240442754306
#     Attrib spectral_flatness_q1    2.724305565499133
# Sigmoid Node 8
#     Inputs    Weights
#     Threshold    0.5917142515854714
#     Attrib pitch_median    0.4874663459726262
#     Attrib pitch_q3    0.896790666534725
#     Attrib pitch_mean    0.573169421324669
#     Attrib pitch_q1    -0.18237205951359092
#     Attrib spectral_contrast_7_iqr    -0.7212280799653455
#     Attrib mfcc_3_mean    -1.3139414569926915
#     Attrib spectral_contrast_7_std_dev    -0.5535372059712385
#     Attrib mfcc_3_q1    -1.5597046224475166
#     Attrib pitch_jitter    -2.6311055892372837
#     Attrib mfcc_3_q3    0.07826464981743175
#     Attrib spectral_contrast_7_q3    -0.7687936039813437
#     Attrib pitch_shimmer    -0.596039436927234
#     Attrib pitch_iqr    0.6078407311418025
#     Attrib pitch_range    0.8944917293828312
#     Attrib spectral_centroid_median    0.9552645357720683
#     Attrib zcr_mean    0.8241124880645434
#     Attrib mfcc_2_mean    0.18597197407519664
#     Attrib mfcc_4_mean    -0.39737636956742417
#     Attrib energy_q1    1.158084401459854
#     Attrib mfcc_2_q3    -0.594213562173195
#     Attrib mfcc_4_max    -1.7805939689004515
#     Attrib spectral_flatness_min    -0.48645824884435773
#     Attrib mfcc_3_median    -0.6276958554158281
#     Attrib zcr_median    0.7001006392192076
#     Attrib pitch_max    0.5455107217442124
#     Attrib zcr_q3    0.913563923254685
#     Attrib spectral_contrast_7_median    0.85150349781235
#     Attrib mfcc_11_mean    -0.599915261424956
#     Attrib spectral_contrast_7_q1    -0.3543596901803614
#     Attrib mfcc_6_median    0.49113297012834384
#     Attrib mfcc_6_q3    -0.2680671684587517
#     Attrib spectral_centroid_q3    -0.8886592514946489
#     Attrib mfcc_3_min    -0.7439637002876318
#     Attrib spectral_contrast_7_mean    -0.5497393217433917
#     Attrib mfcc_4_q1    -0.8556290923076252
#     Attrib mfcc_6_mean    -0.14025136604788116
#     Attrib mfcc_2_max    -2.9046201775985296
#     Attrib spectral_rolloff_median    -1.3017770271392832
#     Attrib pitch_std_dev    1.1284195462521025
#     Attrib mfcc_4_median    0.1853958895825846
#     Attrib spectral_rolloff_mean    0.4258553001177235
#     Attrib mfcc_11_q1    -0.837936886432316
#     Attrib zcr_std_dev    0.6558467218296314
#     Attrib mfcc_6_min    -1.3027037218916264
#     Attrib mfcc_2_q1    0.8072216491267554
#     Attrib mfcc_4_q3    -0.35610913895438484
#     Attrib mfcc_3_max    -0.7629048326619465
#     Attrib mfcc_11_min    0.10960506350671202
#     Attrib spectral_contrast_7_max    0.4149433100077476
#     Attrib mfcc_5_mean    -1.050766750956477
#     Attrib spectral_rolloff_q3    0.33673422931096153
#     Attrib mfcc_11_median    0.3279559518584588
#     Attrib mfcc_5_q3    0.7331837723340024
#     Attrib zcr_q1    0.39575426168044275
#     Attrib spectral_contrast_7_kurtosis    -0.5814409920018415
#     Attrib energy_min    -1.2896138767190177
#     Attrib spectral_contrast_2_q3    1.8316069177179966
#     Attrib zcr_range    0.0917248855095257
#     Attrib spectral_rolloff_q1    0.03371078791847265
#     Attrib mfcc_11_q3    -0.559795156907778
#     Attrib zcr_max    0.6345026509312423
#     Attrib zcr_iqr    0.8815624780435019
#     Attrib formant_1_q1    1.0962735508865884
#     Attrib mfcc_5_max    -1.8557866983976985
#     Attrib mfcc_2_median    0.42607318065254457
#     Attrib spectral_flatness_q1    -1.2087954999537707
# Sigmoid Node 9
#     Inputs    Weights
#     Threshold    -0.20490391672592134
#     Attrib pitch_median    0.04728901993442153
#     Attrib pitch_q3    0.10266075067479973
#     Attrib pitch_mean    0.3913644102074521
#     Attrib pitch_q1    0.2989261782153036
#     Attrib spectral_contrast_7_iqr    0.19249703888490002
#     Attrib mfcc_3_mean    0.1900195660746691
#     Attrib spectral_contrast_7_std_dev    0.13442763852950343
#     Attrib mfcc_3_q1    0.05534088934107789
#     Attrib pitch_jitter    0.002711567812403367
#     Attrib mfcc_3_q3    -0.034553086866945755
#     Attrib spectral_contrast_7_q3    0.08070720177670071
#     Attrib pitch_shimmer    0.2365158598263368
#     Attrib pitch_iqr    -0.018913735263243397
#     Attrib pitch_range    -0.007950506308345278
#     Attrib spectral_centroid_median    0.42878067503277456
#     Attrib zcr_mean    0.06143935743197487
#     Attrib mfcc_2_mean    0.07392568932974221
#     Attrib mfcc_4_mean    -0.1501629240674393
#     Attrib energy_q1    -0.11489116104599152
#     Attrib mfcc_2_q3    0.033217107214261715
#     Attrib mfcc_4_max    -0.1301785668527965
#     Attrib spectral_flatness_min    0.20214574278973435
#     Attrib mfcc_3_median    -0.08869071926393308
#     Attrib zcr_median    0.2636992681082729
#     Attrib pitch_max    0.2142455104554831
#     Attrib zcr_q3    -0.30055796771841076
#     Attrib spectral_contrast_7_median    0.1359792498410132
#     Attrib mfcc_11_mean    -0.06079876726125303
#     Attrib spectral_contrast_7_q1    -0.10085297252610084
#     Attrib mfcc_6_median    0.044692072794181074
#     Attrib mfcc_6_q3    -0.24214515367120434
#     Attrib spectral_centroid_q3    -0.08530584097608984
#     Attrib mfcc_3_min    0.007040694035270027
#     Attrib spectral_contrast_7_mean    -0.016761209142590223
#     Attrib mfcc_4_q1    0.09377078259208291
#     Attrib mfcc_6_mean    -0.042735362978835664
#     Attrib mfcc_2_max    0.2833777758726626
#     Attrib spectral_rolloff_median    0.3285306395838881
#     Attrib pitch_std_dev    -0.10038867205515017
#     Attrib mfcc_4_median    -0.3118405731481432
#     Attrib spectral_rolloff_mean    0.06777095582317157
#     Attrib mfcc_11_q1    -0.25856455743625206
#     Attrib zcr_std_dev    0.014929067228355394
#     Attrib mfcc_6_min    0.09915669375617417
#     Attrib mfcc_2_q1    0.01735194303504926
#     Attrib mfcc_4_q3    -0.011274491751871483
#     Attrib mfcc_3_max    -0.33932586758970606
#     Attrib mfcc_11_min    -0.029978617158887545
#     Attrib spectral_contrast_7_max    0.08085018825052552
#     Attrib mfcc_5_mean    -0.14282027091413735
#     Attrib spectral_rolloff_q3    -0.08767448672750855
#     Attrib mfcc_11_median    -0.050887593483298264
#     Attrib mfcc_5_q3    -0.2566179638011859
#     Attrib zcr_q1    -0.16451712713686176
#     Attrib spectral_contrast_7_kurtosis    0.22131698406171302
#     Attrib energy_min    0.1693878217786877
#     Attrib spectral_contrast_2_q3    0.06106625559382591
#     Attrib zcr_range    -0.11311857104217828
#     Attrib spectral_rolloff_q1    0.03059537028149996
#     Attrib mfcc_11_q3    -0.07915830727964152
#     Attrib zcr_max    -0.22376964773141889
#     Attrib zcr_iqr    0.02798214338614113
#     Attrib formant_1_q1    0.20477430292300736
#     Attrib mfcc_5_max    0.2037816048757411
#     Attrib mfcc_2_median    0.07809742299726728
#     Attrib spectral_flatness_q1    0.40251498332857827
# Sigmoid Node 10
#     Inputs    Weights
#     Threshold    -0.21633718234433708
#     Attrib pitch_median    0.357999033702676
#     Attrib pitch_q3    0.1659162278928852
#     Attrib pitch_mean    0.05584071967076523
#     Attrib pitch_q1    0.22477815532840853
#     Attrib spectral_contrast_7_iqr    0.0894116234654473
#     Attrib mfcc_3_mean    -0.1714672366048621
#     Attrib spectral_contrast_7_std_dev    0.08304762195531348
#     Attrib mfcc_3_q1    -0.1985353977976493
#     Attrib pitch_jitter    0.21096413415405876
#     Attrib mfcc_3_q3    0.03397454135149428
#     Attrib spectral_contrast_7_q3    0.03280552798243807
#     Attrib pitch_shimmer    0.12090957474675869
#     Attrib pitch_iqr    0.20940165220066637
#     Attrib pitch_range    0.11171827119977748
#     Attrib spectral_centroid_median    -0.15561916200414658
#     Attrib zcr_mean    0.1486603363802936
#     Attrib mfcc_2_mean    -0.11519116548479344
#     Attrib mfcc_4_mean    0.04667288667321779
#     Attrib energy_q1    0.12969641345995747
#     Attrib mfcc_2_q3    -0.16343803358685768
#     Attrib mfcc_4_max    -0.1260893368581638
#     Attrib spectral_flatness_min    0.19534161679235884
#     Attrib mfcc_3_median    -0.1376561532291827
#     Attrib zcr_median    0.22775362521433107
#     Attrib pitch_max    0.004365132640092227
#     Attrib zcr_q3    0.20177734109939585
#     Attrib spectral_contrast_7_median    0.04406227007770415
#     Attrib mfcc_11_mean    -0.010131389060879984
#     Attrib spectral_contrast_7_q1    0.0387208113362541
#     Attrib mfcc_6_median    -0.030815343953952835
#     Attrib mfcc_6_q3    0.10861188761354837
#     Attrib spectral_centroid_q3    -0.01884484370584527
#     Attrib mfcc_3_min    -0.06402625681664428
#     Attrib spectral_contrast_7_mean    0.04751463258260522
#     Attrib mfcc_4_q1    -0.12866065656582318
#     Attrib mfcc_6_mean    0.050975119632453415
#     Attrib mfcc_2_max    -0.2989845336671018
#     Attrib spectral_rolloff_median    -0.06988407739930874
#     Attrib pitch_std_dev    0.24209036943205806
#     Attrib mfcc_4_median    0.11008763083078194
#     Attrib spectral_rolloff_mean    -0.08612323192795572
#     Attrib mfcc_11_q1    0.027290152248473386
#     Attrib zcr_std_dev    0.076976896558699
#     Attrib mfcc_6_min    -0.05099598942740612
#     Attrib mfcc_2_q1    -0.0014736540339366272
#     Attrib mfcc_4_q3    0.04315937708500119
#     Attrib mfcc_3_max    0.0704551840578678
#     Attrib mfcc_11_min    0.020493192378579952
#     Attrib spectral_contrast_7_max    -0.05194486683565192
#     Attrib mfcc_5_mean    -0.002989458367215972
#     Attrib spectral_rolloff_q3    -0.06086613131772043
#     Attrib mfcc_11_median    -0.17054300175445042
#     Attrib mfcc_5_q3    0.05456905212476441
#     Attrib zcr_q1    0.30551686664964667
#     Attrib spectral_contrast_7_kurtosis    0.1865640573161115
#     Attrib energy_min    0.14326586115612452
#     Attrib spectral_contrast_2_q3    0.16996066896598538
#     Attrib zcr_range    0.1387224048454503
#     Attrib spectral_rolloff_q1    0.11110771237882394
#     Attrib mfcc_11_q3    -5.9924538453000047E-5
#     Attrib zcr_max    0.09740278537898454
#     Attrib zcr_iqr    0.13154460539636187
#     Attrib formant_1_q1    0.03840885117565187
#     Attrib mfcc_5_max    0.019715889233004765
#     Attrib mfcc_2_median    -0.018404869238441965
#     Attrib spectral_flatness_q1    0.16874508252771014
# Sigmoid Node 11
#     Inputs    Weights
#     Threshold    -0.10501703478078145
#     Attrib pitch_median    0.3378046562711015
#     Attrib pitch_q3    -0.05399110133339533
#     Attrib pitch_mean    -0.06420194721224029
#     Attrib pitch_q1    0.25716668719949226
#     Attrib spectral_contrast_7_iqr    -0.38134249298854184
#     Attrib mfcc_3_mean    0.08304028827956679
#     Attrib spectral_contrast_7_std_dev    -0.4145152962719023
#     Attrib mfcc_3_q1    -0.0980918615346286
#     Attrib pitch_jitter    0.37268008976717576
#     Attrib mfcc_3_q3    0.25622427863153774
#     Attrib spectral_contrast_7_q3    -0.3143812181825737
#     Attrib pitch_shimmer    -0.39583638755605843
#     Attrib pitch_iqr    0.015590387493748303
#     Attrib pitch_range    0.3334517905191184
#     Attrib spectral_centroid_median    -0.22064251904673074
#     Attrib zcr_mean    0.10275524798757034
#     Attrib mfcc_2_mean    -0.0600815826142368
#     Attrib mfcc_4_mean    -0.23251887912991076
#     Attrib energy_q1    -0.2892858164171512
#     Attrib mfcc_2_q3    -0.35930422925817374
#     Attrib mfcc_4_max    -0.11030443852639747
#     Attrib spectral_flatness_min    0.3070680561641128
#     Attrib mfcc_3_median    -0.15717117793007965
#     Attrib zcr_median    0.05504840114613505
#     Attrib pitch_max    -0.10868692230215846
#     Attrib zcr_q3    -0.15956130998089285
#     Attrib spectral_contrast_7_median    0.31096813481492375
#     Attrib mfcc_11_mean    -0.13000802089729382
#     Attrib spectral_contrast_7_q1    0.14560155463783495
#     Attrib mfcc_6_median    0.3283700281164379
#     Attrib mfcc_6_q3    0.10859314665267367
#     Attrib spectral_centroid_q3    -0.600308084597414
#     Attrib mfcc_3_min    -0.275135300751475
#     Attrib spectral_contrast_7_mean    0.008545228447582858
#     Attrib mfcc_4_q1    -0.07901823797242565
#     Attrib mfcc_6_mean    0.21776751654368473
#     Attrib mfcc_2_max    -0.3500457671048962
#     Attrib spectral_rolloff_median    -0.0890803824510789
#     Attrib pitch_std_dev    -0.30471941469432856
#     Attrib mfcc_4_median    -0.20767240984749222
#     Attrib spectral_rolloff_mean    -0.550968105981491
#     Attrib mfcc_11_q1    0.3936503734893675
#     Attrib zcr_std_dev    0.1232989890320269
#     Attrib mfcc_6_min    -0.10079087982237106
#     Attrib mfcc_2_q1    0.41470281909732787
#     Attrib mfcc_4_q3    0.10234623351792045
#     Attrib mfcc_3_max    -0.23727531446008013
#     Attrib mfcc_11_min    0.5851849304251262
#     Attrib spectral_contrast_7_max    -0.39653189545190776
#     Attrib mfcc_5_mean    0.30225074179134165
#     Attrib spectral_rolloff_q3    -0.7795773690251323
#     Attrib mfcc_11_median    0.04094196979879562
#     Attrib mfcc_5_q3    0.16478592430141495
#     Attrib zcr_q1    0.08196737206189465
#     Attrib spectral_contrast_7_kurtosis    0.0659832743106027
#     Attrib energy_min    0.6144565075689004
#     Attrib spectral_contrast_2_q3    -0.38436789493127316
#     Attrib zcr_range    0.3879863817542289
#     Attrib spectral_rolloff_q1    0.27559943792918273
#     Attrib mfcc_11_q3    -0.6091557767124702
#     Attrib zcr_max    -0.020613403240640246
#     Attrib zcr_iqr    -0.16366369312907555
#     Attrib formant_1_q1    -0.11808670539627292
#     Attrib mfcc_5_max    -0.15717406066953032
#     Attrib mfcc_2_median    0.283655845998017
#     Attrib spectral_flatness_q1    0.6423212368466884
# Sigmoid Node 12
#     Inputs    Weights
#     Threshold    -0.38108878330749246
#     Attrib pitch_median    0.36935514398020397
#     Attrib pitch_q3    0.6025666467972847
#     Attrib pitch_mean    1.111078488476326
#     Attrib pitch_q1    0.9050806446365083
#     Attrib spectral_contrast_7_iqr    -0.08692632371289355
#     Attrib mfcc_3_mean    0.45100418026754063
#     Attrib spectral_contrast_7_std_dev    0.2426671852005964
#     Attrib mfcc_3_q1    0.3912351886430657
#     Attrib pitch_jitter    -0.18597249621888942
#     Attrib mfcc_3_q3    0.05481354061468744
#     Attrib spectral_contrast_7_q3    -0.20983174565181675
#     Attrib pitch_shimmer    0.48570268984534526
#     Attrib pitch_iqr    -0.004439155648753773
#     Attrib pitch_range    0.6468103034102223
#     Attrib spectral_centroid_median    0.5899511388130338
#     Attrib zcr_mean    -0.29283051932488274
#     Attrib mfcc_2_mean    0.20747204565943414
#     Attrib mfcc_4_mean    0.08161984229643472
#     Attrib energy_q1    -0.07434567346875816
#     Attrib mfcc_2_q3    -0.1931093107752404
#     Attrib mfcc_4_max    0.1131944290593703
#     Attrib spectral_flatness_min    0.3902292199399379
#     Attrib mfcc_3_median    0.10724382323315786
#     Attrib zcr_median    0.16280081043670216
#     Attrib pitch_max    0.8738686612294
#     Attrib zcr_q3    -0.6237799569636737
#     Attrib spectral_contrast_7_median    0.5603563456598698
#     Attrib mfcc_11_mean    0.05841008387740864
#     Attrib spectral_contrast_7_q1    -0.1965255417283531
#     Attrib mfcc_6_median    -0.13718705372746015
#     Attrib mfcc_6_q3    -0.6723219531237912
#     Attrib spectral_centroid_q3    -0.4635948088813363
#     Attrib mfcc_3_min    -0.47756587409671253
#     Attrib spectral_contrast_7_mean    -0.14647115918883719
#     Attrib mfcc_4_q1    0.5862066862284122
#     Attrib mfcc_6_mean    -0.3577909786321429
#     Attrib mfcc_2_max    0.516596111980917
#     Attrib spectral_rolloff_median    0.4278656819550697
#     Attrib pitch_std_dev    0.17093880394868205
#     Attrib mfcc_4_median    -0.19249666334842316
#     Attrib spectral_rolloff_mean    -0.11476004188001526
#     Attrib mfcc_11_q1    -0.409633184627312
#     Attrib zcr_std_dev    -0.272560450669138
#     Attrib mfcc_6_min    0.4907708506807172
#     Attrib mfcc_2_q1    0.4656510899556148
#     Attrib mfcc_4_q3    0.4225685238877964
#     Attrib mfcc_3_max    -1.014060789516091
#     Attrib mfcc_11_min    0.3210649945434038
#     Attrib spectral_contrast_7_max    0.49304807070021
#     Attrib mfcc_5_mean    -0.598230359279552
#     Attrib spectral_rolloff_q3    -0.5853775694292188
#     Attrib mfcc_11_median    0.25352217593075554
#     Attrib mfcc_5_q3    -0.36996880655630393
#     Attrib zcr_q1    -0.35188394321786487
#     Attrib spectral_contrast_7_kurtosis    0.6487048285980433
#     Attrib energy_min    0.6382473588173041
#     Attrib spectral_contrast_2_q3    0.28715225570037195
#     Attrib zcr_range    -0.3377007622867037
#     Attrib spectral_rolloff_q1    0.028288169512107157
#     Attrib mfcc_11_q3    -0.20420248859917392
#     Attrib zcr_max    -0.6730983814899745
#     Attrib zcr_iqr    -0.17521747481259603
#     Attrib formant_1_q1    0.5350779298337459
#     Attrib mfcc_5_max    0.2021959567053194
#     Attrib mfcc_2_median    0.08271943864586251
#     Attrib spectral_flatness_q1    0.6044039370265957
# Sigmoid Node 13
#     Inputs    Weights
#     Threshold    -0.053639738037080414
#     Attrib pitch_median    0.6061992411092927
#     Attrib pitch_q3    0.1516538577870793
#     Attrib pitch_mean    1.4976054891619381
#     Attrib pitch_q1    1.1529256408776936
#     Attrib spectral_contrast_7_iqr    -0.8532756427281671
#     Attrib mfcc_3_mean    2.173777026408422
#     Attrib spectral_contrast_7_std_dev    -0.17226516270525574
#     Attrib mfcc_3_q1    2.6219127714393875
#     Attrib pitch_jitter    0.20836529711268104
#     Attrib mfcc_3_q3    0.20792311409790903
#     Attrib spectral_contrast_7_q3    -1.06913904243721
#     Attrib pitch_shimmer    1.626977256494516
#     Attrib pitch_iqr    -1.4536727340221236
#     Attrib pitch_range    -0.25728212365446845
#     Attrib spectral_centroid_median    -0.4198950414910164
#     Attrib zcr_mean    -0.9203095297179438
#     Attrib mfcc_2_mean    -0.9079156803075653
#     Attrib mfcc_4_mean    0.9815566826766688
#     Attrib energy_q1    0.4115260264037578
#     Attrib mfcc_2_q3    -2.1370506964777243
#     Attrib mfcc_4_max    1.1857159988865624
#     Attrib spectral_flatness_min    0.22515683615119594
#     Attrib mfcc_3_median    1.0948742691146611
#     Attrib zcr_median    -1.2507008328750004
#     Attrib pitch_max    -0.9002050420483233
#     Attrib zcr_q3    -1.0910122479402644
#     Attrib spectral_contrast_7_median    -0.2583117665764865
#     Attrib mfcc_11_mean    2.095972007557386
#     Attrib spectral_contrast_7_q1    -0.16835466915992786
#     Attrib mfcc_6_median    1.5965757241173097
#     Attrib mfcc_6_q3    -0.4981416761927586
#     Attrib spectral_centroid_q3    0.7776910121081726
#     Attrib mfcc_3_min    1.1030116595740425
#     Attrib spectral_contrast_7_mean    -0.6826136609926328
#     Attrib mfcc_4_q1    0.34315422450555455
#     Attrib mfcc_6_mean    -0.1705482692389709
#     Attrib mfcc_2_max    -1.5040565330991653
#     Attrib spectral_rolloff_median    -0.5381486266626304
#     Attrib pitch_std_dev    -1.5855296443669522
#     Attrib mfcc_4_median    -0.09771684959801608
#     Attrib spectral_rolloff_mean    1.023357266721337
#     Attrib mfcc_11_q1    0.7900688342407896
#     Attrib zcr_std_dev    -0.9437901235314342
#     Attrib mfcc_6_min    -1.8761236103230492
#     Attrib mfcc_2_q1    -0.6883320175147867
#     Attrib mfcc_4_q3    0.29749109221458486
#     Attrib mfcc_3_max    3.8549132987541923
#     Attrib mfcc_11_min    1.2902214407735713
#     Attrib spectral_contrast_7_max    -0.5259480340614031
#     Attrib mfcc_5_mean    -0.5758316922949954
#     Attrib spectral_rolloff_q3    0.7663079438088135
#     Attrib mfcc_11_median    1.1331472188019875
#     Attrib mfcc_5_q3    0.2513233240950382
#     Attrib zcr_q1    -0.8027056298238167
#     Attrib spectral_contrast_7_kurtosis    0.6648272844856261
#     Attrib energy_min    0.945822895643513
#     Attrib spectral_contrast_2_q3    0.8167725010433026
#     Attrib zcr_range    -0.5024515633317611
#     Attrib spectral_rolloff_q1    0.6965029324346814
#     Attrib mfcc_11_q3    -0.4462539593677013
#     Attrib zcr_max    0.1438015245847321
#     Attrib zcr_iqr    -0.10354345947436001
#     Attrib formant_1_q1    -1.1983046034903335
#     Attrib mfcc_5_max    -0.9311546840410975
#     Attrib mfcc_2_median    0.05990034718656551
#     Attrib spectral_flatness_q1    1.3832289611865884
# Sigmoid Node 14
#     Inputs    Weights
#     Threshold    -0.14174681234299052
#     Attrib pitch_median    0.001003803741915844
#     Attrib pitch_q3    -0.07573269233302012
#     Attrib pitch_mean    0.02594424484956259
#     Attrib pitch_q1    0.10223471965660144
#     Attrib spectral_contrast_7_iqr    0.13459679719977904
#     Attrib mfcc_3_mean    0.15081318138040828
#     Attrib spectral_contrast_7_std_dev    0.10755982705999821
#     Attrib mfcc_3_q1    0.07452165087356956
#     Attrib pitch_jitter    0.15158033561071244
#     Attrib mfcc_3_q3    0.060220183277635814
#     Attrib spectral_contrast_7_q3    0.012461731076937033
#     Attrib pitch_shimmer    0.29178659489998493
#     Attrib pitch_iqr    -0.11144915161603611
#     Attrib pitch_range    0.03305460559619758
#     Attrib spectral_centroid_median    0.1111151287978833
#     Attrib zcr_mean    -0.008152962561400535
#     Attrib mfcc_2_mean    0.042837290926107864
#     Attrib mfcc_4_mean    -0.192066023558008
#     Attrib energy_q1    -0.1484764940374655
#     Attrib mfcc_2_q3    0.06324955230233388
#     Attrib mfcc_4_max    0.05008916060601943
#     Attrib spectral_flatness_min    0.17489209360904873
#     Attrib mfcc_3_median    0.036296891568794884
#     Attrib zcr_median    0.1499706257179515
#     Attrib pitch_max    0.03701289429361144
#     Attrib zcr_q3    -0.06150729675598875
#     Attrib spectral_contrast_7_median    -0.10989666784042461
#     Attrib mfcc_11_mean    0.1408362013320983
#     Attrib spectral_contrast_7_q1    -0.052276651885440444
#     Attrib mfcc_6_median    0.05550251548161779
#     Attrib mfcc_6_q3    -0.05869523495254315
#     Attrib spectral_centroid_q3    -0.1385131782320303
#     Attrib mfcc_3_min    0.11226005315193036
#     Attrib spectral_contrast_7_mean    -0.03481815671806169
#     Attrib mfcc_4_q1    -0.024943456754223353
#     Attrib mfcc_6_mean    0.012408432530074311
#     Attrib mfcc_2_max    0.06872617533239797
#     Attrib spectral_rolloff_median    0.06212521587365922
#     Attrib pitch_std_dev    0.04739760472078987
#     Attrib mfcc_4_median    -0.21791940310813818
#     Attrib spectral_rolloff_mean    -0.11648173417027623
#     Attrib mfcc_11_q1    0.010963388609747104
#     Attrib zcr_std_dev    0.06784345675475512
#     Attrib mfcc_6_min    0.056773000612533264
#     Attrib mfcc_2_q1    0.10952785785413138
#     Attrib mfcc_4_q3    -0.06919031462686255
#     Attrib mfcc_3_max    -0.14615548582778534
#     Attrib mfcc_11_min    0.010874297168883076
#     Attrib spectral_contrast_7_max    0.08435704775580066
#     Attrib mfcc_5_mean    -0.0731286710300099
#     Attrib spectral_rolloff_q3    -0.20640239276501107
#     Attrib mfcc_11_median    0.2297314053701418
#     Attrib mfcc_5_q3    -0.10290806925085827
#     Attrib zcr_q1    -0.0022437629842161863
#     Attrib spectral_contrast_7_kurtosis    0.18668285282168393
#     Attrib energy_min    0.12586159636609648
#     Attrib spectral_contrast_2_q3    -0.10230057151326072
#     Attrib zcr_range    -0.1126230363671135
#     Attrib spectral_rolloff_q1    0.05864062335319763
#     Attrib mfcc_11_q3    0.041496421059280864
#     Attrib zcr_max    -0.1555291627449856
#     Attrib zcr_iqr    0.031073179108419013
#     Attrib formant_1_q1    0.1767626229580799
#     Attrib mfcc_5_max    0.07138874345301492
#     Attrib mfcc_2_median    0.04087951661553378
#     Attrib spectral_flatness_q1    0.32450130850807957
# Sigmoid Node 15
#     Inputs    Weights
#     Threshold    -0.4390006328637955
#     Attrib pitch_median    0.1176110706640588
#     Attrib pitch_q3    0.4029313146491075
#     Attrib pitch_mean    0.9917061994098266
# ...
#     Attrib pitch_q3    -0.5084932548698777
#     Attrib pitch_mean    0.05012692312004951
#     Attrib pitch_q1    -0.34270278230116197
#     Attrib spectral_contrast_7_iqr    0.8380362666305573
#     Attrib mfcc_3_mean    0.10720132009754302
#     Attrib spectral_contrast_7_std_dev    0.9776709278024243
#     Attrib mfcc_3_q1    -0.012499467784477617
#     Attrib pitch_jitter    -0.5640119163614609
#     Attrib mfcc_3_q3    0.03763054659908829
#     Attrib spectral_contrast_7_q3    0.8863793275778169
#     Attrib pitch_shimmer    0.3635309509099038
#     Attrib pitch_iqr    -0.2672288657639957
#     Attrib pitch_range    -0.8401594151834558
#     Attrib spectral_centroid_median    -0.262943323137643
#     Attrib zcr_mean    0.1771703993743978
#     Attrib mfcc_2_mean    0.4982449998648565
#     Attrib mfcc_4_mean    0.5260492684198035
#     Attrib energy_q1    0.2755301849536777
#     Attrib mfcc_2_q3    0.5169619094283098
#     Attrib mfcc_4_max    -0.2940248661375803
#     Attrib spectral_flatness_min    -0.0318795224580682
#     Attrib mfcc_3_median    -0.12266004188318252
#     Attrib zcr_median    0.459969214199971
#     Attrib pitch_max    0.15332522481116564
#     Attrib zcr_q3    -0.2882001408483838
#     Attrib spectral_contrast_7_median    0.6982534971791632
#     Attrib mfcc_11_mean    0.05652962871659644
#     Attrib spectral_contrast_7_q1    0.16958172974287145
#     Attrib mfcc_6_median    0.06951772151320944
#     Attrib mfcc_6_q3    -0.4826305318907537
#     Attrib spectral_centroid_q3    -0.3190123329328747
#     Attrib mfcc_3_min    -0.2213450936196701
#     Attrib spectral_contrast_7_mean    0.668400727097529
#     Attrib mfcc_4_q1    0.7790159631291775
#     Attrib mfcc_6_mean    -0.2916674354512501
#     Attrib mfcc_2_max    0.39733002428502007
#     Attrib spectral_rolloff_median    -0.3668891568349283
#     Attrib pitch_std_dev    0.3738518385976231
#     Attrib mfcc_4_median    0.4829189473215992
#     Attrib spectral_rolloff_mean    0.17784570840159095
#     Attrib mfcc_11_q1    -0.5341137793582778
#     Attrib zcr_std_dev    0.2342689920605975
#     Attrib mfcc_6_min    -0.7741290099413145
#     Attrib mfcc_2_q1    0.2757801694038967
#     Attrib mfcc_4_q3    0.34359464941792106
#     Attrib mfcc_3_max    0.008653081864568849
#     Attrib mfcc_11_min    -0.524861885193118
#     Attrib spectral_contrast_7_max    0.7423541084266256
#     Attrib mfcc_5_mean    0.14863024658958177
#     Attrib spectral_rolloff_q3    -0.04645234728927667
#     Attrib mfcc_11_median    -0.188942309378514
#     Attrib mfcc_5_q3    -0.05308433109858138
#     Attrib zcr_q1    -0.2363885958856096
#     Attrib spectral_contrast_7_kurtosis    -0.01419564510290683
#     Attrib energy_min    0.08318067778905146
#     Attrib spectral_contrast_2_q3    0.16038086182423258
#     Attrib zcr_range    0.007122147451529518
#     Attrib spectral_rolloff_q1    -0.29177541250079686
#     Attrib mfcc_11_q3    0.06165268811063357
#     Attrib zcr_max    0.13413895267109208
#     Attrib zcr_iqr    0.008147108523810714
#     Attrib formant_1_q1    0.21731368442687232
#     Attrib mfcc_5_max    0.537830231825938
#     Attrib mfcc_2_median    0.25517538755105157
#     Attrib spectral_flatness_q1    -0.10062469481686152
# Sigmoid Node 69
#     Inputs    Weights
#     Threshold    -1.3762585200178616
#     Attrib pitch_median    -1.7540712298669845
#     Attrib pitch_q3    -1.4166683625196237
#     Attrib pitch_mean    -1.5943871544466819
#     Attrib pitch_q1    -1.06124790912693
#     Attrib spectral_contrast_7_iqr    -0.7241924520003126
#     Attrib mfcc_3_mean    0.11969069469340024
#     Attrib spectral_contrast_7_std_dev    1.3565467720153856
#     Attrib mfcc_3_q1    0.5837095746482
#     Attrib pitch_jitter    0.8680182582805445
#     Attrib mfcc_3_q3    -1.008722742585229
#     Attrib spectral_contrast_7_q3    -0.6511245192730714
#     Attrib pitch_shimmer    2.846513066767482
#     Attrib pitch_iqr    0.3999651013886603
#     Attrib pitch_range    -1.019349435410978
#     Attrib spectral_centroid_median    -1.1892054772140201
#     Attrib zcr_mean    0.9104061338700838
#     Attrib mfcc_2_mean    0.8553668652908963
#     Attrib mfcc_4_mean    0.706961536765963
#     Attrib energy_q1    0.5849767262481722
#     Attrib mfcc_2_q3    0.17043351170700938
#     Attrib mfcc_4_max    0.5401802626308809
#     Attrib spectral_flatness_min    2.09070916026645
#     Attrib mfcc_3_median    0.9610681699657921
#     Attrib zcr_median    1.4211357839622374
#     Attrib pitch_max    -0.6062578660481244
#     Attrib zcr_q3    0.7697284643475887
#     Attrib spectral_contrast_7_median    -0.8165992152879886
#     Attrib mfcc_11_mean    0.6994495231772936
#     Attrib spectral_contrast_7_q1    1.0550666243752123
#     Attrib mfcc_6_median    0.06684320910589506
#     Attrib mfcc_6_q3    -0.5937504575493694
#     Attrib spectral_centroid_q3    0.46921233624868525
#     Attrib mfcc_3_min    0.04801736970249644
#     Attrib spectral_contrast_7_mean    0.5845445238281395
#     Attrib mfcc_4_q1    2.339654735760959
#     Attrib mfcc_6_mean    -1.5177035480908563
#     Attrib mfcc_2_max    3.2721536093817507
#     Attrib spectral_rolloff_median    -1.1385679703684006
#     Attrib pitch_std_dev    -1.658537557691871
#     Attrib mfcc_4_median    1.5339030277152716
#     Attrib spectral_rolloff_mean    0.6522594486614356
#     Attrib mfcc_11_q1    -0.04781806915333901
#     Attrib zcr_std_dev    0.6674404831665208
#     Attrib mfcc_6_min    0.014855470716551213
#     Attrib mfcc_2_q1    -1.3510168879184201
#     Attrib mfcc_4_q3    -0.6364446139012256
#     Attrib mfcc_3_max    1.9899755687614737
#     Attrib mfcc_11_min    0.09861124739352843
#     Attrib spectral_contrast_7_max    0.9430804861213489
#     Attrib mfcc_5_mean    1.160247357896186
#     Attrib spectral_rolloff_q3    1.4281116317184088
#     Attrib mfcc_11_median    0.7019588257534322
#     Attrib mfcc_5_q3    0.663199834867879
#     Attrib zcr_q1    1.8067706097851832
#     Attrib spectral_contrast_7_kurtosis    0.7149191972137711
#     Attrib energy_min    0.2977169102724373
#     Attrib spectral_contrast_2_q3    -3.2273911830781317
#     Attrib zcr_range    -1.0073816080112896
#     Attrib spectral_rolloff_q1    0.34028528849302436
#     Attrib mfcc_11_q3    1.7902005031231376
#     Attrib zcr_max    0.37922278326065795
#     Attrib zcr_iqr    0.10238336031794155
#     Attrib formant_1_q1    0.5199144648419974
#     Attrib mfcc_5_max    0.423341057821657
#     Attrib mfcc_2_median    -0.5945107781843154
#     Attrib spectral_flatness_q1    1.0366846163248673
# Sigmoid Node 70
#     Inputs    Weights
#     Threshold    0.0021505139538980133
#     Attrib pitch_median    -0.04167340291950334
#     Attrib pitch_q3    -0.0713908573514545
#     Attrib pitch_mean    0.12830877235087587
#     Attrib pitch_q1    0.13294604732475995
#     Attrib spectral_contrast_7_iqr    0.27766338124845563
#     Attrib mfcc_3_mean    0.1131434204147823
#     Attrib spectral_contrast_7_std_dev    0.20953834477066213
#     Attrib mfcc_3_q1    -0.01028639590484893
#     Attrib pitch_jitter    0.1366866860415504
#     Attrib mfcc_3_q3    -0.12990077647484796
#     Attrib spectral_contrast_7_q3    0.08848298174352791
#     Attrib pitch_shimmer    0.23416332736958087
#     Attrib pitch_iqr    -0.0566254248852725
#     Attrib pitch_range    0.04153677893531921
#     Attrib spectral_centroid_median    0.17468234075819006
#     Attrib zcr_mean    0.0439251729156982
#     Attrib mfcc_2_mean    0.0658640121210783
#     Attrib mfcc_4_mean    -0.19942593512463455
#     Attrib energy_q1    -0.2642423350352397
#     Attrib mfcc_2_q3    0.20655735653044935
#     Attrib mfcc_4_max    -0.12564214176667934
#     Attrib spectral_flatness_min    0.04955042247408671
#     Attrib mfcc_3_median    -0.026489541480714533
#     Attrib zcr_median    0.26184563990073967
#     Attrib pitch_max    -0.053574988467108536
#     Attrib zcr_q3    -0.1698516983362368
#     Attrib spectral_contrast_7_median    -0.09352979901569962
#     Attrib mfcc_11_mean    -0.04307071035664916
#     Attrib spectral_contrast_7_q1    -0.14875762857735264
#     Attrib mfcc_6_median    0.10431676414085661
#     Attrib mfcc_6_q3    -0.05643650910664081
#     Attrib spectral_centroid_q3    -0.12827842652304267
#     Attrib mfcc_3_min    0.3115828855072743
#     Attrib spectral_contrast_7_mean    -0.12022785733428408
#     Attrib mfcc_4_q1    -0.019225879358701424
#     Attrib mfcc_6_mean    0.07852764952955994
#     Attrib mfcc_2_max    0.17094240539707714
#     Attrib spectral_rolloff_median    0.1183671298013124
#     Attrib pitch_std_dev    0.05897421920109797
#     Attrib mfcc_4_median    -0.22610161203926435
#     Attrib spectral_rolloff_mean    -0.03144881460855203
#     Attrib mfcc_11_q1    -0.35737174404310945
#     Attrib zcr_std_dev    -0.04554214960860224
#     Attrib mfcc_6_min    0.1893386198120176
#     Attrib mfcc_2_q1    -0.030400999401610534
#     Attrib mfcc_4_q3    -0.13908117656629468
#     Attrib mfcc_3_max    -0.37165698785697454
#     Attrib mfcc_11_min    -0.1426727207541764
#     Attrib spectral_contrast_7_max    -0.013828745889324819
#     Attrib mfcc_5_mean    0.02494251224380814
#     Attrib spectral_rolloff_q3    -0.18429249657178134
#     Attrib mfcc_11_median    0.24629157336752386
#     Attrib mfcc_5_q3    -0.027850360256041387
#     Attrib zcr_q1    -0.10052032339811784
#     Attrib spectral_contrast_7_kurtosis    0.11949145700907408
#     Attrib energy_min    0.014190556696206228
#     Attrib spectral_contrast_2_q3    -0.05991218662321773
#     Attrib zcr_range    -0.2229452312693153
#     Attrib spectral_rolloff_q1    0.11642554102041332
#     Attrib mfcc_11_q3    -0.014183624623682244
#     Attrib zcr_max    -0.33897987415400543
#     Attrib zcr_iqr    0.004958962273254743
#     Attrib formant_1_q1    0.045537707402879754
#     Attrib mfcc_5_max    0.12424524472165809
#     Attrib mfcc_2_median    -0.03603609022210283
#     Attrib spectral_flatness_q1    0.33540241847846425
# Sigmoid Node 71
#     Inputs    Weights
#     Threshold    -0.1720264578487313
#     Attrib pitch_median    0.907841170425749
#     Attrib pitch_q3    0.5552549235202743
#     Attrib pitch_mean    0.09576023528787586
#     Attrib pitch_q1    0.33191083230580193
#     Attrib spectral_contrast_7_iqr    -0.20806457938592868
#     Attrib mfcc_3_mean    0.005414992977029785
#     Attrib spectral_contrast_7_std_dev    -0.030594169491761348
#     Attrib mfcc_3_q1    -0.29618301060520674
#     Attrib pitch_jitter    0.5855056282775162
#     Attrib mfcc_3_q3    0.4465930026830127
#     Attrib spectral_contrast_7_q3    -0.20557108695390172
#     Attrib pitch_shimmer    0.13687203409470025
#     Attrib pitch_iqr    0.9442123108444825
#     Attrib pitch_range    0.8648768189716246
#     Attrib spectral_centroid_median    -0.5261843019992568
#     Attrib zcr_mean    0.3204077856365654
#     Attrib mfcc_2_mean    0.042452495321380485
#     Attrib mfcc_4_mean    -0.14173303711239052
#     Attrib energy_q1    0.3882646420827756
#     Attrib mfcc_2_q3    -0.15385202110172044
#     Attrib mfcc_4_max    -0.0990936834034099
#     Attrib spectral_flatness_min    -8.912048988804037E-4
#     Attrib mfcc_3_median    -0.129820175343813
#     Attrib zcr_median    0.3312752606656675
#     Attrib pitch_max    0.4686983606754082
#     Attrib zcr_q3    0.5251549144113752
#     Attrib spectral_contrast_7_median    -0.075735128457444
#     Attrib mfcc_11_mean    -0.23412065497273427
#     Attrib spectral_contrast_7_q1    0.11621753979146836
#     Attrib mfcc_6_median    -0.2825725566848436
#     Attrib mfcc_6_q3    0.18678551899923349
#     Attrib spectral_centroid_q3    -0.5148050455104441
#     Attrib mfcc_3_min    0.7727858385916831
#     Attrib spectral_contrast_7_mean    -0.09353964530460632
#     Attrib mfcc_4_q1    -0.7134750705543127
#     Attrib mfcc_6_mean    -0.07504136568345139
#     Attrib mfcc_2_max    -0.24224442379307595
#     Attrib spectral_rolloff_median    -0.2987978200728329
#     Attrib pitch_std_dev    0.19153767073473296
#     Attrib mfcc_4_median    0.659858748302138
#     Attrib spectral_rolloff_mean    -0.2896029704898219
#     Attrib mfcc_11_q1    -0.01105029201735764
#     Attrib zcr_std_dev    0.2821326391844763
#     Attrib mfcc_6_min    0.22806346333822777
#     Attrib mfcc_2_q1    0.17352109257455683
#     Attrib mfcc_4_q3    0.02295992139692632
#     Attrib mfcc_3_max    0.26569028490120133
#     Attrib mfcc_11_min    -0.4095588334169595
#     Attrib spectral_contrast_7_max    -0.7130806420024269
#     Attrib mfcc_5_mean    0.18877515447493085
#     Attrib spectral_rolloff_q3    -0.3496291125597834
#     Attrib mfcc_11_median    -0.4938173891163848
#     Attrib mfcc_5_q3    0.5968020243621888
#     Attrib zcr_q1    0.45038526159349584
#     Attrib spectral_contrast_7_kurtosis    0.20242607472408292
#     Attrib energy_min    -0.39081686308647323
#     Attrib spectral_contrast_2_q3    -0.23722528585230784
#     Attrib zcr_range    -0.06930372725321242
#     Attrib spectral_rolloff_q1    -0.46803720439827257
#     Attrib mfcc_11_q3    0.4320680469307335
#     Attrib zcr_max    -0.04374603694189958
#     Attrib zcr_iqr    0.19321447531672215
#     Attrib formant_1_q1    -0.2093505801512549
#     Attrib mfcc_5_max    0.47130380917524084
#     Attrib mfcc_2_median    0.019442641952469163
#     Attrib spectral_flatness_q1    -0.3125352224628561
# Class negative
#     Input
#     Node 0
# Class positive
#     Input
#     Node 1
# Class neutral
#     Input
#     Node 2
#
#
# MultiClassClassifier
#
# Classifier 1, 1 vs 2
# RandomForest
#
# Bagging with 100 iterations and base learner
#
# weka.classifiers.trees.RandomTree -K 0 -M 1.0 -V 0.001 -S 1 -do-not-check-capabilities
#
# Classifier 2, 1 vs 3
# RandomForest
#
# Bagging with 100 iterations and base learner
#
# weka.classifiers.trees.RandomTree -K 0 -M 1.0 -V 0.001 -S 1 -do-not-check-capabilities
#
# Classifier 3, 2 vs 3
# RandomForest
#
# Bagging with 100 iterations and base learner
#
# weka.classifiers.trees.RandomTree -K 0 -M 1.0 -V 0.001 -S 1 -do-not-check-capabilities
#
#
#
# RandomForest
#
# Bagging with 100 iterations and base learner
#
# weka.classifiers.trees.RandomTree -K 0 -M 1.0 -V 0.001 -S 1 -do-not-check-capabilities
#
#
#
# Meta classifier
#
# Logistic Regression with ridge parameter of 1.0E-8
# Coefficients...
#                                                                    Class
# Variable                                                        negative    positive
# ====================================================================================
# weka.classifiers.functions.MultilayerPerceptron-1:negative        1.3422      0.8191
# weka.classifiers.functions.MultilayerPerceptron-1:positive       -0.7608      0.0908
# weka.classifiers.functions.MultilayerPerceptron-1:neutral        -0.7729     -0.8881
# weka.classifiers.meta.MultiClassClassifier-2:negative             0.2712     -0.5031
# weka.classifiers.meta.MultiClassClassifier-2:positive             1.5179      1.3818
# weka.classifiers.meta.MultiClassClassifier-2:neutral             -1.1425     -0.7843
# weka.classifiers.trees.RandomForest-3:negative                     4.708      0.4784
# weka.classifiers.trees.RandomForest-3:positive                    2.3885      9.3761
# weka.classifiers.trees.RandomForest-3:neutral                    -3.6235     -4.6414
# Intercept                                                          0.094     -0.3738
#
#
# Odds Ratios...
#                                                                    Class
# Variable                                                        negative    positive
# ====================================================================================
# weka.classifiers.functions.MultilayerPerceptron-1:negative        3.8276      2.2685
# weka.classifiers.functions.MultilayerPerceptron-1:positive        0.4673       1.095
# weka.classifiers.functions.MultilayerPerceptron-1:neutral         0.4617      0.4114
# weka.classifiers.meta.MultiClassClassifier-2:negative             1.3115      0.6046
# weka.classifiers.meta.MultiClassClassifier-2:positive             4.5628       3.982
# weka.classifiers.meta.MultiClassClassifier-2:neutral               0.319      0.4564
# weka.classifiers.trees.RandomForest-3:negative                  110.8338      1.6135
# weka.classifiers.trees.RandomForest-3:positive                   10.8976  11803.1071
# weka.classifiers.trees.RandomForest-3:neutral                     0.0267      0.0096
#
# <weka.classifiers.Classifier object at 0x000002179DCA60D0>

# %%
# Start the audio stream
import weka.core
from weka.core.dataset import Instance
import weka.core.dataset


stream.start()

print("Recording... Press 'q' to stop.")
# Wait for the user to press 'q' to stop recording
try:
    while True:
        if keyboard.is_pressed('q'):
            print("Stopping recording...")
            break
        if len(buf) > sr * 5:
            # Get the last 5 seconds of audio from the buffer
            segment = np.array(list(buf))[-sr*5:]
            feats = extract_features(segment, sr)
            print("Extracted features:", feats)
            # Convert the features to a DataFrame
            df = pd.DataFrame([feats])
            df = df[attributes]
            print("DataFrame:", df)
            # Scale the features using the loaded scaler
            scaled_features = scaler.transform(df)
            scaled_features = np.array(scaled_features, dtype=np.float32)[0]  # Convert to float32
            print("Scaled features:", scaled_features)
            # Create a new Weka instance with the same structure as the header
            # Create a new Weka instance with the same structure as the header
            weka_instance = Instance.create_instance(scaled_features)
            # Set the dataset for the instance
            
            # Set the class attribute to missing (since we want to predict it)
            weka_instance.set_missing(header.class_index)
            
            # Classify the instance using the loaded model
            predictions = list(cls.predict(weka_instance))  # Get the class distribution
            print(f"Predictions: {predictions}")
            # Get the predicted class label
            if predictions:  # Ensure the list is not empty
                pred_index = int(predictions[0])  # Get the first prediction (class index)
                predicted_class = header.class_attribute.value(pred_index)  # Map index to class label
                print(f"Predicted class index: {pred_index}")
                print(f"Predicted class: {predicted_class}")
            else:
                print("No predictions were made.")
        print("sleeping...")
        sleep(1.0)
finally:
    stream.stop()
# Out:
# Recording... Press 'q' to stop.
# sleeping...
# sleeping...
# sleeping...
# sleeping...
# sleeping...
# sleeping...
# Extracted features: {'mfcc_1_mean': np.float32(-37.73904), 'mfcc_1_median': np.float32(-39.27087), 'mfcc_1_std_dev': np.float32(11.023379), 'mfcc_1_min': np.float32(-89.41008), 'mfcc_1_max': np.float32(21.420504), 'mfcc_1_q1': np.float32(-42.265976), 'mfcc_1_q3': np.float32(-35.777973), 'mfcc_1_iqr': np.float64(6.488002777099609), 'mfcc_1_jitter': np.float32(4.1202164), 'mfcc_1_shimmer': np.float32(5.8618894), 'mfcc_1_skewness': np.float64(1.7403428554534912), 'mfcc_1_kurtosis': np.float32(12.14225), 'mfcc_1_peak_count': 36, 'mfcc_1_range': np.float32(110.83058), 'mfcc_1_delta_mean': np.float32(0.07915878), 'mfcc_1_delta_median': np.float32(0.051525846), 'mfcc_1_delta_std_dev': np.float32(1.6430992), 'mfcc_1_delta_min': np.float32(-7.3605328), 'mfcc_1_delta_max': np.float32(5.0753207), 'mfcc_1_delta_q1': np.float32(-0.71832746), 'mfcc_1_delta_q3': np.float32(0.64703286), 'mfcc_1_delta_iqr': np.float64(1.3653603196144104), 'mfcc_1_delta_jitter': np.float32(0.524618), 'mfcc_1_delta_shimmer': np.float32(0.6186395), 'mfcc_1_delta_skewness': np.float64(-0.29440298676490784), 'mfcc_1_delta_kurtosis': np.float32(4.040125), 'mfcc_1_delta_peak_count': 18, 'mfcc_1_delta_range': np.float32(12.435854), 'mfcc_1_delta2_mean': np.float32(-0.16038144), 'mfcc_1_delta2_median': np.float32(-0.07799528), 'mfcc_1_delta2_std_dev': np.float32(1.3513252), 'mfcc_1_delta2_min': np.float32(-5.1881385), 'mfcc_1_delta2_max': np.float32(5.2579727), 'mfcc_1_delta2_q1': np.float32(-0.6214154), 'mfcc_1_delta2_q3': np.float32(0.50830543), 'mfcc_1_delta2_iqr': np.float64(1.1297208070755005), 'mfcc_1_delta2_jitter': np.float32(0.5856437), 'mfcc_1_delta2_shimmer': np.float32(0.76662624), 'mfcc_1_delta2_skewness': np.float64(-0.5114482045173645), 'mfcc_1_delta2_kurtosis': np.float32(3.3760076), 'mfcc_1_delta2_peak_count': 27, 'mfcc_1_delta2_range': np.float32(10.446112), 'mfcc_2_mean': np.float32(79.207375), 'mfcc_2_median': np.float32(81.97359), 'mfcc_2_std_dev': np.float32(9.623345), 'mfcc_2_min': np.float32(34.81083), 'mfcc_2_max': np.float32(92.42265), 'mfcc_2_q1': np.float32(77.28066), 'mfcc_2_q3': np.float32(84.12494), 'mfcc_2_iqr': np.float64(6.844276428222656), 'mfcc_2_jitter': np.float32(3.40589), 'mfcc_2_shimmer': np.float32(4.0672235), 'mfcc_2_skewness': np.float64(-2.513484001159668), 'mfcc_2_kurtosis': np.float32(7.568137), 'mfcc_2_peak_count': 39, 'mfcc_2_range': np.float32(57.611824), 'mfcc_2_delta_mean': np.float32(-0.007582288), 'mfcc_2_delta_median': np.float32(-0.02677218), 'mfcc_2_delta_std_dev': np.float32(1.4019213), 'mfcc_2_delta_min': np.float32(-5.9821234), 'mfcc_2_delta_max': np.float32(4.8284197), 'mfcc_2_delta_q1': np.float32(-0.60797536), 'mfcc_2_delta_q3': np.float32(0.7836014), 'mfcc_2_delta_iqr': np.float64(1.3915767669677734), 'mfcc_2_delta_jitter': np.float32(0.44959015), 'mfcc_2_delta_shimmer': np.float32(0.48502567), 'mfcc_2_delta_skewness': np.float64(-0.7916722893714905), 'mfcc_2_delta_kurtosis': np.float32(4.566038), 'mfcc_2_delta_peak_count': 21, 'mfcc_2_delta_range': np.float32(10.810543), 'mfcc_2_delta2_mean': np.float32(-0.02765933), 'mfcc_2_delta2_median': np.float32(0.013304838), 'mfcc_2_delta2_std_dev': np.float32(1.0185782), 'mfcc_2_delta2_min': np.float32(-3.835869), 'mfcc_2_delta2_max': np.float32(4.908306), 'mfcc_2_delta2_q1': np.float32(-0.4514835), 'mfcc_2_delta2_q3': np.float32(0.27648523), 'mfcc_2_delta2_iqr': np.float64(0.7279687225818634), 'mfcc_2_delta2_jitter': np.float32(0.45886397), 'mfcc_2_delta2_shimmer': np.float32(0.63314), 'mfcc_2_delta2_skewness': np.float64(1.008625864982605), 'mfcc_2_delta2_kurtosis': np.float32(5.991297), 'mfcc_2_delta2_peak_count': 24, 'mfcc_2_delta2_range': np.float32(8.744175), 'mfcc_3_mean': np.float32(-10.07917), 'mfcc_3_median': np.float32(-10.575157), 'mfcc_3_std_dev': np.float32(6.236137), 'mfcc_3_min': np.float32(-20.383703), 'mfcc_3_max': np.float32(23.23312), 'mfcc_3_q1': np.float32(-14.003969), 'mfcc_3_q3': np.float32(-7.75838), 'mfcc_3_iqr': np.float64(6.245589256286 ...
# DataFrame:    pitch_q3  pitch_median  pitch_mean  pitch_q1  spectral_centroid_q1  \
# 0         0             0           0         0           1952.802715
#
#    mfcc_3_mean  pitch_shimmer  mfcc_3_q1  spectral_flatness_q1  pitch_jitter  \
# 0    -10.07917              0 -14.003969              0.081943             0
#
#    ...  energy_iqr  energy_jitter  energy_kurtosis  energy_max  energy_mean  \
# 0  ...    0.005941       0.003018         8.392192    0.129217     0.093258
#
#    energy_median  energy_peak_count  energy_q3  energy_range  energy_shimmer
# 0       0.092344                 30   0.096064      0.071961         0.00377
#
# [1 rows x 71 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 26
#      24 print("DataFrame:", df)
#      25 # Scale the features using the loaded scaler
# ---> 26 scaled_features = scaler.transform(df)
#      27 scaled_features = np.array(scaled_features, dtype=np.float32)[0]  # Convert to float32
#      28 print("Scaled features:", scaled_features)
#
# File c:\Users\jbkee\Desktop\Jupyter-Projects\.venv\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File c:\Users\jbkee\Desktop\Jupyter-Projects\.venv\Lib\site-packages\sklearn\preprocessing\_data.py:1062, in StandardScaler.transform(self, X, copy)
#    1059 check_is_fitted(self)
#    1061 copy = copy if copy is not None else self.copy
# -> 1062 X = validate_data(
#    1063     self,
#    1064     X,
#    1065     reset=False,
#    1066     accept_sparse="csr",
#    1067     copy=copy,
#    1068     dtype=FLOAT_DTYPES,
#    1069     force_writeable=True,
#    1070     ensure_all_finite="allow-nan",
#    1071 )
#    1073 if sparse.issparse(X):
#    1074     if self.with_mean:
#
# File c:\Users\jbkee\Desktop\Jupyter-Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2919, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2835 def validate_data(
#    2836     _estimator,
#    2837     /,
#    (...)   2843     **check_params,
#    2844 ):
#    2845     """Validate input data and set or check feature names and counts of the input.
#    2846
#    2847     This helper function should be used in an estimator that requires input
#    (...)   2917         validated.
#    2918     """
# -> 2919     _check_feature_names(_estimator, X, reset=reset)
#    2920     tags = get_tags(_estimator)
#    2921     if y is None and tags.target_tags.required:
#
# File c:\Users\jbkee\Desktop\Jupyter-Projects\.venv\Lib\site-packages\sklearn\utils\validation.py:2777, in _check_feature_names(estimator, X, reset)
#    2774 if not missing_names and not unexpected_names:
#    2775     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2777 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names seen at fit time, yet now missing:
# - energy_skewness
# - energy_std_dev
# - formant_1_iqr
# - formant_1_jitter
# - formant_1_kurtosis
# - ...

# %%
jvm.stop()

# %%
# Start the audio stream
import weka.core
import weka.core.dataset


# with sd.InputStream(samplerate=sr, channels=1, callback=audio_callback):
#     print("Recording... Press 'q' to stop.")
#     while True:
#         if keyboard.is_pressed('q'):
#             break

#         # Check if we have enough data in the buffer
#         if len(buf) == buf.maxlen:
#             audio_data = np.array(buf).astype(np.float32)

#             # Extract features from the audio data
#             features = extract_features(audio_data, sr)

#             # Convert features to DataFrame for Weka
#             df = pd.DataFrame([features])

#             # Scale the features using the loaded scaler
#             scaled_features = scaler.transform(df)

#             # Extract attribute names from the ARFF header
#             attribute_names = [header.attribute(i).name for i in range(header.num_attributes - 1)]  # Exclude the class attribute

#             # Create an empty DataFrame with the attribute names as columns
#             filtered_features = pd.DataFrame(columns=attribute_names, index=[0])

#             # Map scaled features to the DataFrame
#             for i in range(header.num_attributes - 1):  # Exclude the class attribute
#                 attr_name = header.attribute(i).name
#                 if attr_name in df.columns:
#                     filtered_features[attr_name] = scaled_features[0][df.columns.get_loc(attr_name)]
#             # Convert the filtered features DataFrame to a list of values
#             feature_values = filtered_features.iloc[0].tolist()
#             print(type(feature_values), type(header))
#             weka_instance = weka.core.dataset.Instance.create_instance(header, feature_values)
#             weka_instance.set_dataset(header)
#             weka_instance.set_class_value(0)
            
#             # Classify the instance
#             prediction = list(cls.predict(weka_instance, verbose=True, distribution=True))
#             print(f"Predicted class index: {prediction}")
#             class_label = header.class_attribute.value(prediction)

#             print(f"Predicted class: {class_label}")

# # Stop the audio stream
# sd.stop()

# %%
# stream.stop()
jvm.stop()
